# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/langchain-ai/langchain-academy/blob/main/module-3/streaming-interruption.ipynb) [![Open in LangChain Academy](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66e9eba12c7b7688aa3dbb5e_LCA-badge-green.svg)](https://academy.langchain.com/courses/take/intro-to-langgraph/lessons/58239464-lesson-1-streaming)

# %% [markdown]
# # Streaming
#
# ## Review
#
# In module 2, covered a few ways to customize graph state and memory.
#
# We built up to a Chatbot with external memory that can sustain long-running conversations.
#
# ## Goals
#
# This module will dive into `human-in-the-loop`, which builds on memory and allows users to interact directly with graphs in various ways.
#
# To set the stage for `human-in-the-loop`, we'll first dive into streaming, which provides several ways to visualize graph output (e.g., node state or chat model tokens) over the course of execution.

# %%
# %%capture --no-stderr
# %pip install --quiet -U langgraph langchain_openai langgraph_sdk

# %% [markdown]
# ## Streaming
#
# LangGraph is built with [first class support for streaming](https://docs.langchain.com/oss/python/langgraph/streaming).
#
# Let's set up our Chatbot from Module 2, and show various way to stream outputs from the graph during execution.

# %%
import os, getpass


def _set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"{var}: ")


_set_env("OPENAI_API_KEY")
_set_env("OPENAI_BASE_URL")
_set_env("OPENAI_MODEL")
_set_env("DEEPSEEK_V4_FLASH")

# %% [markdown]
# Note that we use `RunnableConfig` with `call_model` to enable token-wise streaming. This is [only needed with python < 3.11](https://langchain-ai.github.io/langgraph/how-tos/streaming-tokens/). We include in case you are running this notebook in CoLab, which will use python 3.x.

# %%
from IPython.display import Image, display
from typing import Literal

from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage, RemoveMessage
from langchain_core.runnables import RunnableConfig

from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import StateGraph, START, END
from langgraph.graph import MessagesState

# LLM
model = ChatOpenAI(model=os.getenv("DEEPSEEK_V4_FLASH"), temperature=0)


# State
class State(MessagesState):
    summary: str


# Define the logic to call the model
def call_model(state: State, config: RunnableConfig):

    # Get summary if it exists
    summary = state.get("summary", "")

    # If there is summary, then we add it
    if summary:

        # Add summary to system message
        system_message = f"Summary of conversation earlier: {summary}"

        # Append summary to any newer messages
        messages = [SystemMessage(content=system_message)] + state["messages"]

    else:
        messages = state["messages"]

    response = model.invoke(messages, config)
    return {"messages": response}


def summarize_conversation(state: State):

    # First, we get any existing summary
    summary = state.get("summary", "")

    # Create our summarization prompt
    if summary:

        # A summary already exists
        summary_message = (
            f"This is summary of the conversation to date: {summary}\n\n"
            "Extend the summary by taking into account the new messages above:"
        )

    else:
        summary_message = "Create a summary of the conversation above:"

    # Add prompt to our history
    messages = state["messages"] + [HumanMessage(content=summary_message)]
    response = model.invoke(messages)

    # Delete all but the 2 most recent messages
    delete_messages = [RemoveMessage(id=m.id) for m in state["messages"][:-2]]
    return {"summary": response.content, "messages": delete_messages}


# Determine whether to end or summarize the conversation
def should_continue(state: State) -> Literal["summarize_conversation", END]:
    """Return the next node to execute."""

    messages = state["messages"]

    # If there are more than six messages, then we summarize the conversation
    if len(messages) > 6:
        return "summarize_conversation"

    # Otherwise we can just end
    return END


# Define a new graph
workflow = StateGraph(State)
workflow.add_node("conversation", call_model)
workflow.add_node(summarize_conversation)

# Set the entrypoint as conversation
workflow.add_edge(START, "conversation")
workflow.add_conditional_edges("conversation", should_continue)
workflow.add_edge("summarize_conversation", END)

# Compile
memory = MemorySaver()
graph = workflow.compile(checkpointer=memory)
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# ### Streaming full state
#
# Now, let's talk about ways to [stream our graph state](https://docs.langchain.com/oss/python/langgraph/streaming#supported-stream-modes).
#
# `.stream` and `.astream` are sync and async methods for streaming back results.
#
# LangGraph supports a few [different streaming modes](https://docs.langchain.com/oss/python/langgraph/streaming#stream-graph-state) for graph state.
#
# - `values`: This streams the full state of the graph after each node is called.
# - `updates`: This streams updates to the state of the graph after each node is called.
#
# ![values_vs_updates.png](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66dbaf892d24625a201744e5_streaming1.png)
#
# Let's look at `stream_mode="updates"`.
#
# Because we stream with `updates`, we only see updates to the state after node in the graph is run.
#
# Each `chunk` is a dict with `node_name` as the key and the updated state as the value.

# %%
# Create a thread
config = {"configurable": {"thread_id": "1"}}

# Start conversation
for chunk in graph.stream(
    {"messages": [HumanMessage(content="hi! I'm Lance")]}, config, stream_mode="updates"
):
    print(chunk)
# Out:
# {'conversation': {'messages': AIMessage(content='Hi Lance! Great to meet you. How can I help you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 9, 'total_tokens': 25, 'completion_tokens_details': None, 'prompt_tokens_details': None, 'audio_prompt_tokens': 0}, 'model_provider': 'openai', 'model_name': 'DeepSeek-V4-Flash', 'system_fingerprint': None, 'id': '8678b0f0c1204f9d96675f08bef41bfb', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0bfc5-05dc-70f2-99cb-efa70bae72f5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 9, 'output_tokens': 16, 'total_tokens': 25, 'input_token_details': {}, 'output_token_details': {}})}}

# %% [markdown]
# Let's now just print the state update.

# %%
# Start conversation
for chunk in graph.stream(
    {"messages": [HumanMessage(content="hi! I'm Lance")]}, config, stream_mode="updates"
):
    chunk["conversation"]["messages"].pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Hey Lance! Welcome back. 😊
#
# What's on your mind today? Whether you have a question, need help with something, or just want to chat, I'm here for you.

# %% [markdown]
# Now, we can see `stream_mode="values"`.
#
# This is the `full state` of the graph after the `conversation` node is called.

# %%
# Start conversation, again
config = {"configurable": {"thread_id": "2"}}

# Start conversation
input_message = HumanMessage(content="hi! I'm Lance")
for event in graph.stream({"messages": [input_message]}, config, stream_mode="values"):
    for m in event["messages"]:
        m.pretty_print()
    print("---" * 25)
# Out:
# ================================ Human Message =================================
#
# hi! I'm Lance
# ---------------------------------------------------------------------------
# ================================ Human Message =================================
#
# hi! I'm Lance
# ================================== Ai Message ==================================
#
# Hi Lance! Great to meet you. How can I help you today?
# ---------------------------------------------------------------------------

# %% [markdown]
# ### Streaming tokens
#
# We often want to stream more than graph state.
#
# In particular, with chat model calls it is common to stream the tokens as they are generated.
#
# We can do this [using the `.astream_events` method](https://docs.langchain.com/oss/python/langchain/models#advanced-streaming-topics:streaming-events), which streams back events as they happen inside nodes!
#
# Each event is a dict with a few keys:
#
# - `event`: This is the type of event that is being emitted.
# - `name`: This is the name of event.
# - `data`: This is the data associated with the event.
# - `metadata`: Contains`langgraph_node`, the node emitting the event.
#
# Let's have a look.

# %%
config = {"configurable": {"thread_id": "3"}}
input_message = HumanMessage(content="Tell me about the 49ers NFL team")
async for event in graph.astream_events(
    {"messages": [input_message]}, config, version="v2"
):
    print(
        f"Node: {event['metadata'].get('langgraph_node','')}. Type: {event['event']}. Name: {event['name']}"
    )
# Out:
# Node: . Type: on_chain_start. Name: LangGraph
# Node: conversation. Type: on_chain_start. Name: conversation
# Node: conversation. Type: on_chat_model_start. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_end. Name: ChatOpenAI
# Node: conversation. Type: on_chain_start. Name: should_continue
# Node: conversation. Type: on_chain_end. Name: should_continue
# Node: conversation. Type: on_chain_stream. Name: conversation
# Node: conversation. Type: on_chain_end. Name: conversation
# Node: . Type: on_chain_stream. Name: LangGraph
# Node: . Type: on_chain_end. Name: LangGraph

# %% [markdown]
# The central point is that tokens from chat models within your graph have the `on_chat_model_stream` type.
#
# We can use `event['metadata']['langgraph_node']` to select the node to stream from.
#
# And we can use `event['data']` to get the actual data for each event, which in this case is an `AIMessageChunk`.

# %%
node_to_stream = "conversation"
config = {"configurable": {"thread_id": "4"}}
input_message = HumanMessage(content="Tell me about the 49ers NFL team")
async for event in graph.astream_events(
    {"messages": [input_message]}, config, version="v2"
):
    # Get chat model tokens from a particular node
    if (
        event["event"] == "on_chat_model_stream"
        and event["metadata"].get("langgraph_node", "") == node_to_stream
    ):
        print(event["data"])
# Out:
# {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Here', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' is a comprehensive', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' overview of the San', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Francisco 49', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ers, one', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' of the most stor', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ied and', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' successful franchises', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' in NFL', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' history.\n\n###', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Quick', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Facts', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='\n\n- **', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Full Name:**', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' San Francisco 49', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ers\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='- **Location', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=':** Santa', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Clara, California', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (about', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' 45', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' miles south', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' of San', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Francisco)\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='- **St', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='adium:**', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=" Levi's Stadium", additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (op', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ened in', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' 2014)\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='- **Conference', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=':** National', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Football Conference', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (NFC)\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='- **Division', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=':** NFC', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' West\n- **', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Team', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Colors:** Gold', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=', Cardinal', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Red, and', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Met', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='allic Gold\n-', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **M', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ascot:**', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Sourdough', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Sam\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='- **Super', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Bowl Championships', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=':** 5 (', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='1981,', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' 1984', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=', 1988', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=', 1989', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=', 199', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='4)\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='- **N', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='FC Championships', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=':** 8', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='1981,', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' 1984,', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' 1988,', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' 1989,', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' 1994,', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' 2012,', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' 2019,', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' 2023)\n\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='---\n\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='### The "', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='D', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ynasty', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='" Era (', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='1981', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='-199', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='4)\n\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='This is the', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' period', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' that defines', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the 49', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ers.', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Under', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the leadership', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' of legendary', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' head coach **Bill', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Walsh**', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' and later', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **George', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Seif', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ert**, the', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' team won', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' five', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Super Bow', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ls in ', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='14 years.\n\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='- **The', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' West', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Coast Off', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ense:** Bill', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Walsh revolutionized', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' football', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' with the "West', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Coast Off', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ense."', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' It', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' emphasized', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' short,', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' precise', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' passing routes', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' to control', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the clock', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' and move', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the ball down', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the field, rather', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' than relying', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' on a', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' power', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' running game.', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' This system', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' became the', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' blueprint', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' for many', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' NFL teams', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='.\n-', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **Joe', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Montana (', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='QB', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='):** Ar', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='guably', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the greatest quarterback', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' of all', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' time.', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' "', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Joe', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Cool" was famous', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' for his', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' unflapp', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='able demeanor', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' incredible', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' accuracy, and', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' clutch', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' performances,', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' especially in Super', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Bowls (', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='4', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='-0', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' record, ', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='11', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' T', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Ds, 0', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' INTs).', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' His most', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' famous play', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' is "', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='The Catch"', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (1981', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' NFC Championship', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=') to Dwight', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Clark.\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='- **Jer', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ry Rice', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (WR):**', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Widely considered', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the greatest wide', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' receiver in', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' NFL history.', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' He', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' holds nearly', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' every major receiving', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' record (', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='care', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='er recept', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ions, yards', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=', and', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' touchdowns). His', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' work ethic and', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' route', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='-running were', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' unmatched.\n- **', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Ronnie L', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ott (DB', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='):** A', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' fierce', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=', hard', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='-hitting safety', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' cornerback who', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' was the', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' heart and', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' soul of the', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' defense. He', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' was a', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' 10-time', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Pro Bow', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ler and', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' a key leader', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' on all', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' four of', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the 80', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='s Super', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Bowl teams', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='.\n- **Key', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Super', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Bowl Wins:**\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='    -', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **Super Bowl XVI', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (1981):', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='** Def', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='eated the', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# ...
# {'chunk': AIMessageChunk(content=' playoff games, especially', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' between', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Montana/F', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='avre', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' and Young', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='/F', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='avre.\n\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='### Why', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' People', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Love (', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='or Hate)', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the 49ers', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='\n\n- **Love', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=':** The', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' rich', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' history, the', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' iconic uniforms', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the innovative', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' offense', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=', the passionate', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' fan base', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ("N', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='iner Faith', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ful"), and', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the under', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='dog story', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' of Brock', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Purdy.\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='- **H', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ate:** The', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' success', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' of the dynasty', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' era', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=', the "', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='band', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='wagon"', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' fans,', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the perceived', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' arrogance of the', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' organization, and', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the recent', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' playoff', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' losses', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' to the Chiefs', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='.\n\nIn', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' short, the San', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Francisco 49ers', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' are a blue', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='-blood', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' franchise', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' with a glorious', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' past, a', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' talented present', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=', and', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' a burning', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' desire to add', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' to', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' their legacy', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='. They', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' are one', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' of the most', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' exciting and', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' compelling', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' teams to watch in', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the NFL.', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'DeepSeek-V4-Flash', 'model_provider': 'openai'}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 1727, 'total_tokens': 1740, 'input_token_details': {}, 'output_token_details': {}}, tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--01a0bfc6-3691-74b1-a8bb-5fc7cda9f3e7', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[], chunk_position='last')}

# %% [markdown]
# As you see above, just use the `chunk` key to get the `AIMessageChunk`.

# %%
config = {"configurable": {"thread_id": "5"}}
input_message = HumanMessage(content="Tell me about the 49ers NFL team")
async for event in graph.astream_events(
    {"messages": [input_message]}, config, version="v2"
):
    # Get chat model tokens from a particular node
    if (
        event["event"] == "on_chat_model_stream"
        and event["metadata"].get("langgraph_node", "") == node_to_stream
    ):
        data = event["data"]
        print(data["chunk"].content, end="|")
# Out:
# |Here| is a comprehensive| overview of the San| Francisco 49|ers, one| of the most stor|ied and| successful franchises| in NFL history.
#
# |### Quick| Facts|
#
# - **|Full Name:**| San Francisco 49|ers
# |- **Location|:** Santa| Clara, California| (about| 45| miles south| of San Francisco|)
# - **|Stadium:** Levi|'s Stadium| (op|ened in| 2014)
# |- **Conference|:** National| Football Conference| (NFC)
# |- **Division|:** NFC| West
# - **|Team Colors:**| Gold|, Cardinal| Red, and| Metallic Gold|
# - **|Masc|ot:**| Sourdough| Sam
# |- **R|ivals:**| Los| Angeles Rams|,| Seattle Seahawks,| Dallas Cowboys,| Green Bay Packers|
# - **|Owner|:** Jed| York
# |- **General| Manager:** John| Lynch
# |- **Head Coach|:** Kyle| Shanahan
#
# |### History| & The| Glory| Years (|The Montana| &| Young| Er|as)
#
# The| 49ers'| identity| was| forged in the |1980s and| 1990s|, when they became| the NFL's first| "|dynasty|" of the modern| era.
#
# - **|The Bill| Walsh Era (|1979|-1988|):** Head| coach Bill Walsh| revolutionized| the game| with his| **"|West Coast Off|ense"|** —|a short, precise| passing attack that| relied| on timing| and yards| after the catch|. He| drafted a| relatively| unknown quarterback from| Notre Dame named| **Joe Montana**|.
# - **Joe| Montana &| The| 80|s Dynasty|:** Montana|,| with| his legendary| calm under| pressure ("|Joe Cool"),| led the| 49ers| to four| Super Bowl victories| in the 198|0s (|X|VI, XIX|, XX|III, XXIV|). He| was supported| by Hall| of Fam|ers like| wide receiver **Jer|ry Rice|**| (the greatest| WR| of all| time), safety| **|Ronnie L|ott**, and defensive| end| **Charles Haley|**.
# - **|The Steve Young| Era (199|1-199|9):** After| Montana's departure|, **|Steve Young|**—|a left|-handed,| dual-threat quarterback|—ste|pped in| and| continued the| winning| tradition. He| led| the 49ers| to a fifth| Super Bowl title| (XXIX)| in 1994|, throwing| a| record six| touchdown passes| in the game|. Young| is| also a Hall| of Famer.
#
# |**|Super| Bowl Wins (|5):**
# |- **X|VI (198|1):|** Def|eated Cincinnati| Bengals |26-21|
# - **|XIX (|1984):|** Defeated| Miami Dolphins |38-16|
# - **|XXIII (198|8):** Def|eated Cincinnati| Bengals |20-16| (f|amous game|-winning drive by| Montana)
# -| **XXIV| (1989):|** Def|eated Denver| Broncos 55|-10| (larg|est margin| of victory in| a Super Bowl)
# |- **XX|IX (|1994):|** Def|eated San| Diego Chargers |49-26|
#
# ### The Modern| Era (|201|0s|-Present)
#
# |After a long| playoff| drought in| the 2000|s, the| 49ers have| returned to prominence|.
#
# |- **The Harb|augh Era| (201|1-2014|):** Head| coach Jim| Harbaugh and| quarterback **|Col|in Kaeper|nick** led| the team| to three| straight NFC| Championship games| and a Super| Bowl X|LVII appearance|, where| they lost to| the Baltimore| Ravens in| a close| game.
# |- **The Shan|ahan-L|ynch Era| (2017|-Present):|** This| current regime| has| rebuilt| the team| into a perennial| powerhouse|,| known for its| dominant| defense and| creative, run|-heavy offense|.
#     -| **201|9 Season|:** Led| by quarterback| **Jim|my Gar|oppolo|**, the| 49ers| reached| Super Bowl LIV| but| lost to the| Kansas City Chiefs| in a dramatic| fourth-quarter| comeback.
#     -| **202|3 Season|:** Led| by quarterback| **B|rock Pur|dy** (|the last| pick of the |2022 draft|, "Mr|. Irrelevant"),| the 49|ers had| the best| record in the| NFC and| reached Super| Bowl LV|III. They| lost again| to the Kansas| City Chiefs in| overtime,| a heartbreaking| defeat.
#
# ###| Key Players (|Current &| Recent|)
#
# - **|Brock Pur|dy (QB|):** The| surprising| star who| took over| in| 2022 and| has been incredibly| efficient, leading| a| high|-powered offense.
# |- **Christian| McCaffrey| (RB|):** The| |2023| NFL| Offensive Player of| the Year.| A versatile|, do|-e|verything| running back who| is the engine| of the offense.
# |- **De|ebo Samuel| (WR|):** A| unique "|wide back|" who| is as| dangerous running| the ball as| he is| catching it|.
# - **|George Kittle| (TE):**| One of the best| tight ends in| the NFL|, known| for his| elite blocking and| big|-play receiving| ability.
# - **|Trent| Williams (OT|):** Wid|ely considered| the best| offensive tackle in| football, a| future| Hall of F|amer.
# - **|Nick Bosa| (DE):|** The| 2022| NFL Defensive Player| of the Year|,| a dominant pass| rusher.
# |- **Fred| Warner (|LB):**| The leader| of the defense|, a| three-time All|-Pro linebacker| who| is elite| in coverage and run| defense|.
#
# ### Team| Identity &| Culture
#
# -| **Off|ense:**| A| version| of the West| Coast Off|ense,| heavily reliant| on **|play|-action**,| **m|otion**,| and **run|-pass| options| (RPOs|)** .| They| love| to run| the ball with| McC|affrey and| use| De|ebo Samuel| in creative| ways.
# - **|Defense:**| A **|4-3| base defense|** that| is aggressive|, fast|, and| physical|. They| are known for their| "wide|-|9" defensive| line technique|,| which allows pass| rushers like| B|osa to get| up|field| quickly.
# - **|Culture:**| The team| pr|ides itself| on a "|next man| up" mentality|, physical|ity|, and a| family|-like atmosphere| fostered| by Kyle| Shanahan and| John Lynch.
#
# ###| The "Cur|se" of| the 199|0s|?
#
# Despite| their incredible| success|, the| 49ers have| not| won a Super| Bowl since| 1994|. They have come| agonizingly| close,| losing in the| Super Bowl in| 2012|, 2019|, and 202|3. This| |30-year drought| is a| source of immense| frustration for the fan|base,| especially given their| recent| dominance.
#
# |### Summary|
#
# The| San Francisco 49|ers are a **|blue-blood| NFL| franchise** with| a rich history| of innovation|, Hall| of Fame| players, and| five Super| Bowl titles|. After| a period| of decline|, they| have re|-emerged| as one| of the most| talented and well|-coached teams| in the league|, consistently| competing| for championships|. Their| ultimate| goal is to| finally break| their| 30-year title| drought and add| a sixth Lombardi| Trophy.||||

# %% [markdown]
# ### Streaming with LangGraph API
#
# **⚠️ Notice**
#
# Since filming these videos, we've updated Studio so that it can now be run locally and accessed through your browser. This is the preferred way to run Studio instead of using the Desktop App shown in the video. It is now called _LangSmith Studio_ instead of _LangGraph Studio_. Detailed setup instructions are available in the "Getting Setup" guide at the start of the course. You can find a description of Studio [here](https://docs.langchain.com/langsmith/studio), and specific details for local deployment [here](https://docs.langchain.com/langsmith/quick-start-studio#local-development-server).
# To start the local development server, run the following command in your terminal in the `/studio` directory in this module:
#
# ```
# langgraph dev
# ```
#
# You should see the following output:
#
# ```
# - 🚀 API: http://127.0.0.1:2024
# - 🎨 Studio UI: https://smith.langchain.com/studio/?baseUrl=http://127.0.0.1:2024
# - 📚 API Docs: http://127.0.0.1:2024/docs
# ```
#
# Open your browser and navigate to the **Studio UI** URL shown above.
#
# The LangGraph API [supports editing graph state](https://docs.langchain.com/langsmith/add-human-in-the-loop).

# %%
if "google.colab" in str(get_ipython()):
    raise Exception(
        "Unfortunately LangGraph Studio is currently not supported on Google Colab"
    )

# %%
from langgraph_sdk import get_client

# This is the URL of the local development server
URL = "http://127.0.0.1:2024"
client = get_client(url=URL)

# Search all hosted graphs
assistants = await client.assistants.search()

# %% [markdown]
# Let's [stream `values`](https://docs.langchain.com/oss/python/langgraph/streaming#stream-graph-state), like before.

# %%
# Create a new thread
thread = await client.threads.create()
# Input message
input_message = HumanMessage(content="Multiply 2 and 3")
async for event in client.runs.stream(
    thread["thread_id"],
    assistant_id="agent",
    input={"messages": [input_message]},
    stream_mode="values",
):
    print(event)
# Out:
# StreamPart(event='metadata', data={'run_id': '01a0bfc6-dd84-7850-8839-8f21d2c02467', 'attempt': 1}, id=None)
# StreamPart(event='values', data={'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '46858433-f5fc-49ff-86ad-99a881975e59'}]}, id=None)
# StreamPart(event='values', data={'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '46858433-f5fc-49ff-86ad-99a881975e59'}, {'content': '\n\n', 'additional_kwargs': {'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 60, 'prompt_tokens': 473, 'total_tokens': 533, 'completion_tokens_details': None, 'prompt_tokens_details': None, 'audio_prompt_tokens': 0}, 'model_provider': 'openai', 'model_name': 'DeepSeek-V4-Flash', 'system_fingerprint': None, 'id': '4e48b6ccd23e43c6907ee44eefc7fc36', 'finish_reason': 'tool_calls', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'lc_run--01a0bfc6-e1e9-7141-92f8-527db595abad-0', 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'call_83ebefdd9f974b63a44eaf3d', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 473, 'output_tokens': 60, 'total_tokens': 533, 'input_token_details': {}, 'output_token_details': {}}}]}, id=None)
# StreamPart(event='values', data={'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '46858433-f5fc-49ff-86ad-99a881975e59'}, {'content': '\n\n', 'additional_kwargs': {'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 60, 'prompt_tokens': 473, 'total_tokens': 533, 'completion_tokens_details': None, 'prompt_tokens_details': None, 'audio_prompt_tokens': 0}, 'model_provider': 'openai', 'model_name': 'DeepSeek-V4-Flash', 'system_fingerprint': None, 'id': '4e48b6ccd23e43c6907ee44eefc7fc36', 'finish_reason': 'tool_calls', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'lc_run--01a0bfc6-e1e9-7141-92f8-527db595abad-0', 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'call_83ebefdd9f974b63a44eaf3d', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 473, 'output_tokens': 60, 'total_tokens': 533, 'input_token_details': {}, 'output_token_details': {}}}, {'content': '6', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': '4d5e5547-49c5-4482-9207-f97b0c8148cc', 'tool_call_id': 'call_83ebefdd9f974b63a44eaf3d', 'artifact': None, 'status': 'success'}]}, id=None)
# StreamPart(event='values', data={'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '46858433-f5fc-49ff-86ad-99a881975e59'}, {'content': '\n\n', 'additional_kwargs': {'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 60, 'prompt_tokens': 473, 'total_tokens': 533, 'completion_tokens_details': None, 'prompt_tokens_details': None, 'audio_prompt_tokens': 0}, 'model_provider': 'openai', 'model_name': 'DeepSeek-V4-Flash', 'system_fingerprint': None, 'id': '4e48b6ccd23e43c6907ee44eefc7fc36', 'finish_reason': 'tool_calls', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'lc_run--01a0bfc6-e1e9-7141-92f8-527db595abad-0', 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'call_83ebefdd9f974b63a44eaf3d', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 473, 'output_tokens': 60, 'total_tokens': 533, 'input_token_details': {}, 'output_token_details': {}}}, {'content': '6', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': '4d5e5547-49c5-4482-9207-f97b0c8148cc', 'tool_call_id': 'call_83ebefdd9f974b63a44eaf3d', 'artifact': None, 'status': 'success'}, {'content': 'The result of multiplying 2 and 3 is **6**.', 'additional_kwargs': {'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 14, 'prompt_tokens': 545, 'total_tokens': 559, 'completion_tokens_details': None, 'prompt_tokens_details': None, 'audio_prompt_tokens': 0}, 'model_provider': 'openai', 'model_name': 'DeepSeek-V4-Flash', 'system_fingerprint': None, 'id': 'df4f88d8057a40cdb425e138174ddf1d', 'finish_reason': 'stop', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'lc_run--01a0bfc6-e6e2-78d1-92b6-1ee3dba41c75-0', 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 545, 'output_tokens': 14, 'total_tokens': 559, 'input_token_details': {}, 'output_token_details': {}}}]}, id=None)

# %% [markdown]
# The streamed objects have:
#
# - `event`: Type
# - `data`: State

# %%
from langchain_core.messages import convert_to_messages

thread = await client.threads.create()
input_message = HumanMessage(content="Multiply 2 and 3")
async for event in client.runs.stream(
    thread["thread_id"],
    assistant_id="agent",
    input={"messages": [input_message]},
    stream_mode="values",
):
    messages = event.data.get("messages", None)
    if messages:
        print(convert_to_messages(messages)[-1])
    print("=" * 25)
# Out:
# =========================
# content='Multiply 2 and 3' additional_kwargs={} response_metadata={} id='42deed43-ed9e-4a68-a109-a5c3d0887603'
# =========================
# content='\n\n' additional_kwargs={'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 473, 'output_tokens': 60, 'total_tokens': 533, 'input_token_details': {}, 'output_token_details': {}}, 'refusal': None} response_metadata={'token_usage': {'completion_tokens': 60, 'prompt_tokens': 473, 'total_tokens': 533, 'completion_tokens_details': None, 'prompt_tokens_details': None, 'audio_prompt_tokens': 0}, 'model_provider': 'openai', 'model_name': 'DeepSeek-V4-Flash', 'system_fingerprint': None, 'id': '754b6c755ab24e5ea0381fe1796d9fec', 'finish_reason': 'tool_calls', 'logprobs': None} id='lc_run--01a0bfc7-eb5c-7c01-b46d-61c573cce3e1-0' tool_calls=[{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'call_2a44155faea6443ba4cece99', 'type': 'tool_call'}] invalid_tool_calls=[]
# =========================
# content='6' name='multiply' id='85076cd2-d861-4b1c-8e3e-5ca1c052b08b' tool_call_id='call_2a44155faea6443ba4cece99'
# =========================
# content='The result of multiplying 2 and 3 is **6**.' additional_kwargs={'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 545, 'output_tokens': 14, 'total_tokens': 559, 'input_token_details': {}, 'output_token_details': {}}, 'refusal': None} response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 545, 'total_tokens': 559, 'completion_tokens_details': None, 'prompt_tokens_details': None, 'audio_prompt_tokens': 0}, 'model_provider': 'openai', 'model_name': 'DeepSeek-V4-Flash', 'system_fingerprint': None, 'id': '1eb6d5217e0b4859bce2da2bc0d6174c', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--01a0bfc7-ef6d-7ad0-9c50-17b56232ca3f-0' tool_calls=[] invalid_tool_calls=[]
# =========================

# %% [markdown]
# There are some new streaming mode that are only supported via the API.
#
# For example, we can [use `messages` mode](https://docs.langchain.com/oss/python/langgraph/streaming#supported-stream-modes) to better handle the above case!
#
# This mode currently assumes that you have a `messages` key in your graph, which is a list of messages.
#
# All events emitted using `messages` mode have two attributes:
#
# - `event`: This is the name of the event
# - `data`: This is data associated with the event

# %%
thread = await client.threads.create()
input_message = HumanMessage(content="Multiply 2 and 3")
async for event in client.runs.stream(
    thread["thread_id"],
    assistant_id="agent",
    input={"messages": [input_message]},
    stream_mode="messages",
):
    print(event.event)
# Out:
# metadata
# messages/metadata
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/metadata
# messages/complete
# messages/metadata
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial

# %% [markdown]
# We can see a few events:
#
# - `metadata`: metadata about the run
# - `messages/complete`: fully formed message
# - `messages/partial`: chat model tokens
#
# <!--You can dig further into the types [~here~](https://langchain-ai.github.io/langgraph/cloud/concepts/api/#modemessages) [here](https://docs.langchain.com/oss/python/langgraph/concepts/langgraph_server). -->
#
# Now, let's show how to stream these messages.
#
# We'll define a helper function for better formatting of the tool calls in messages.

# %%
thread = await client.threads.create()
input_message = HumanMessage(content="Multiply 2 and 3")


def format_tool_calls(tool_calls):
    """
    Format a list of tool calls into a readable string.

    Args:
        tool_calls (list): A list of dictionaries, each representing a tool call.
            Each dictionary should have 'id', 'name', and 'args' keys.

    Returns:
        str: A formatted string of tool calls, or "No tool calls" if the list is empty.

    """

    if tool_calls:
        formatted_calls = []
        for call in tool_calls:
            formatted_calls.append(
                f"Tool Call ID: {call['id']}, Function: {call['name']}, Arguments: {call['args']}"
            )
        return "\n".join(formatted_calls)
    return "No tool calls"


async for event in client.runs.stream(
    thread["thread_id"],
    assistant_id="agent",
    input={"messages": [input_message]},
    stream_mode="messages",
):

    # Handle metadata events
    if event.event == "metadata":
        print(f"Metadata: Run ID - {event.data['run_id']}")
        print("-" * 50)

    # Handle partial message events
    elif event.event == "messages/partial":
        for data_item in event.data:
            # Process user messages
            if "role" in data_item and data_item["role"] == "user":
                print(f"Human: {data_item['content']}")
            else:
                # Extract relevant data from the event
                tool_calls = data_item.get("tool_calls", [])
                invalid_tool_calls = data_item.get("invalid_tool_calls", [])
                content = data_item.get("content", "")
                response_metadata = data_item.get("response_metadata", {})

                if content:
                    print(f"AI: {content}")

                if tool_calls:
                    print("Tool Calls:")
                    print(format_tool_calls(tool_calls))

                if invalid_tool_calls:
                    print("Invalid Tool Calls:")
                    print(format_tool_calls(invalid_tool_calls))

                if response_metadata and response_metadata.get("finish_reason"):
                    print(
                        f"Response Metadata: Finish Reason - {response_metadata['finish_reason']}"
                    )
        print("-" * 50)
# Out:
# Metadata: Run ID - 01a0bfcb-c007-7543-a1d1-f43596ecc28c
# --------------------------------------------------
# --------------------------------------------------
# AI:
#
#
# --------------------------------------------------
# AI:
#
#
# Tool Calls:
# Tool Call ID: call_4c5a9eaa917f4014bc091694, Function: multiply, Arguments: {}
# --------------------------------------------------
# AI:
#
#
# Tool Calls:
# Tool Call ID: call_4c5a9eaa917f4014bc091694, Function: multiply, Arguments: {}
# --------------------------------------------------
# AI:
#
#
# Tool Calls:
# Tool Call ID: call_4c5a9eaa917f4014bc091694, Function: multiply, Arguments: {'a': 2}
# --------------------------------------------------
# AI:
#
#
# Tool Calls:
# Tool Call ID: call_4c5a9eaa917f4014bc091694, Function: multiply, Arguments: {'a': 2, 'b': 3}
# --------------------------------------------------
# AI:
#
#
# Tool Calls:
# Tool Call ID: call_4c5a9eaa917f4014bc091694, Function: multiply, Arguments: {'a': 2, 'b': 3}
# Response Metadata: Finish Reason - tool_calls
# --------------------------------------------------
# AI:
#
#
# Tool Calls:
# Tool Call ID: call_4c5a9eaa917f4014bc091694, Function: multiply, Arguments: {'a': 2, 'b': 3}
# Response Metadata: Finish Reason - tool_calls
# --------------------------------------------------
# AI:
#
#
# Tool Calls:
# Tool Call ID: call_4c5a9eaa917f4014bc091694, Function: multiply, Arguments: {'a': 2, 'b': 3}
# Response Metadata: Finish Reason - tool_calls
# --------------------------------------------------
# --------------------------------------------------
# AI: The
# --------------------------------------------------
# AI: The result of multiplying
# --------------------------------------------------
# AI: The result of multiplying 2 and
# --------------------------------------------------
# AI: The result of multiplying 2 and 3 is
# --------------------------------------------------
# AI: The result of multiplying 2 and 3 is **6**.
# --------------------------------------------------
# AI: The result of multiplying 2 and 3 is **6**.
# Response Metadata: Finish Reason - stop
# --------------------------------------------------
# AI: The result of multiplying 2 and 3 is **6**.
# Response Metadata: Finish Reason - stop
# --------------------------------------------------
# AI: The result of multiplying 2 and 3 is **6**.
# Response Metadata: Finish Reason - stop
# --------------------------------------------------
